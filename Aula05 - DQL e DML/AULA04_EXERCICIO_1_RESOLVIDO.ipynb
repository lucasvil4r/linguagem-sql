# %% [markdown]
# Galera, bom dia!
# Segue resposta do exercicio 1 de ontem. Tivemos muitos problemas no ambiente de vocês para conectar com o SQL. Isso é recorrente, conseguimos instalar na grande maioria das máquinas. Porém não sei se todos os alunos conseguiram acessar a base de dados. Ontem tentamos também pelo Colab, mas ele não possuia os driver necessários instalados, então pesquisei como fazer a instalação e já disponibilizei o código para voces. É o comando abaixo:

# %%
# %%sh
# curl https://packages.microsoft.com/keys/microsoft.asc | apt-key add -
# curl https://packages.microsoft.com/config/ubuntu/16.04/prod.list > /etc/apt/sources.list.d/mssql-release.list
# sudo apt-get update
# sudo ACCEPT_EULA=Y apt-get -q -y install msodbcsql17
# sudo pip install pyodbc
# sudo pip install sqlalchemy
# sudo pip install mysqlclient

# %%
import sqlalchemy, pandas as pd,pyodbc
server =  'ec2-23-21-245-38.compute-1.amazonaws.com' #servidor
database = 'FIT_2022' #banco
username = 'aluno' #usuario
password = 'aluno123' #senha
con1 = f"mssql+pyodbc://{username}:{password}@{server}/{database}?driver=ODBC Driver 17 for SQL Server"
engine = sqlalchemy.create_engine(url = con1)
engine.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3360         try:
# -> 3361             return fn()
#    3362         except dialect.dbapi.Error as e:
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/pool/base.py in connect(self)
#     319         """
# --> 320         return _ConnectionFairy._checkout(self)
#     321
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     883         if not fairy:
# --> 884             fairy = _ConnectionRecord.checkout(pool)
#     885
#
# /usr/local/lib/python3.7/dist-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     485     def checkout(cls, pool):
# --> 486         rec = pool._do_get()
#     487         try:
#
# ...

# %%
df = pd.read_csv("")

# %%
df = pd.read_sql("industrias",engine)
df
# Out:
#        id   ano code                                             nome  \
# 0       1  2011    A                Agriculture, Forestry and Fishing
# 1       2  2011    A                Agriculture, Forestry and Fishing
# 2       3  2011    A                Agriculture, Forestry and Fishing
# 3       4  2011    A                Agriculture, Forestry and Fishing
# 4       5  2011    A                Agriculture, Forestry and Fishing
# ..    ...   ...  ...                                              ...
# 995   996  2011    M  Professional, Scientific and Technical Services
# 996   997  2011    M  Professional, Scientific and Technical Services
# 997   998  2011    M  Professional, Scientific and Technical Services
# 998   999  2011    M  Professional, Scientific and Technical Services
# 999  1000  2011    M  Professional, Scientific and Technical Services
#
#      tamanho                                         variavel  valor  \
# ...

# %%
#Conectando com o banco de dados 
#Reparem que agora o driver não é mais SQL SERVER e sim ODBC Driver 17 for SQL Server
import sqlalchemy, pandas as pd,pyodbc
server =  'database-2.cpbnkeufuawz.us-east-1.rds.amazonaws.com'
database = 'FIT_2022'
username = 'aluno'
password = 'aluno123'
#engine = create_engine("mysql:///?User=myUser&;Password=myPassword&Database=NorthWind&Server=myServer&Port=3306")
con1 = f'mysql://{username}:{password}@{server}/{database}'
engine_mysql = sqlalchemy.create_engine(con1)
engine_mysql.connect()

# %%
engine_mysql.execute("create database FIT_2022")

# %%
df.to_sql("industrias",engine_mysql)

# %%
df = pd.read_sql("select * from industrias",con = engine_mysql)
df
# Out:
#      index    id   ano code                                             nome  \
# 0        0     1  2011    A                Agriculture, Forestry and Fishing
# 1        1     2  2011    A                Agriculture, Forestry and Fishing
# 2        2     3  2011    A                Agriculture, Forestry and Fishing
# 3        3     4  2011    A                Agriculture, Forestry and Fishing
# 4        4     5  2011    A                Agriculture, Forestry and Fishing
# ..     ...   ...   ...  ...                                              ...
# 995    995   996  2011    M  Professional, Scientific and Technical Services
# 996    996   997  2011    M  Professional, Scientific and Technical Services
# 997    997   998  2011    M  Professional, Scientific and Technical Services
# 998    998   999  2011    M  Professional, Scientific and Technical Services
# 999    999  1000  2011    M  Professional, Scientific and Technical Services
#
# ...

# %%
query = "SELECT TABLE_NAME FROM INFORMATION_SCHEMA.TABLES" 
df = pd.read_sql(query,con = engine)
df
# Out:
#                  TABLE_NAME
# 0  FUNCIONARIO_2021_edu.sql
# 1      funcionario_2021.csv

# %%
query = "SELECT TABLE_NAME FROM INFORMATION_SCHEMA.TABLES" 
df = pd.read_sql(query,con = engine)
df
for a,i in df.iterrows():
  tabela = i['TABLE_NAME']
  try:
    
    engine.execute(f" drop table  {tabela}")
  except:
    print(tabela)
# Out:
# FUNCIONARIO_2021_edu.sql
# funcionario_2021.csv

# %%
engine.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-a94d5c2d3822> in <module>()
# ----> 1 engine.close()
#
# AttributeError: 'Engine' object has no attribute 'close'

# %%
#Aqui estou criando um dataframe para cada tabela (FUNCIONARIO,PRODUTO,SERVICO)
df_funcionario = pd.read_sql(sql ="SELECT * FROM FUNCIONARIO",con=engine)
df_produto = pd.read_sql(sql ="SELECT * FROM PRODUTO ",con=engine)
df_servico = pd.read_sql(sql ="SELECT * FROM SERVICO",con=engine)

# %%
#Para cada dataframe, estou salvando um arquivo no repositório sample_data (FUNCIONARIO,PRODUTO,SERVICO)
#Para acessar esse dado, só ir na aba ao lado esquerdo e clicar na "pasta"
df_funcionario.to_csv("sample_data/funcionario.csv",index=False, line_terminator='\n')
df_produto.to_csv("sample_data/produto.csv",index=False, line_terminator='\n')
df_servico.to_csv("sample_data/servico.csv",index=False, line_terminator='\n')
df_servico.to_csv("sample_data/cliente.csv",index=False, line_terminator='\n')

# %%
#Agora vamos ler os csvs gerados anteriormente para inserir do banco de dados dataeng_stage:
df_servico = pd.read_csv("/content/clientes.csv",delimiter = ';', encoding = "ISO-8859-1")
df_funcionario= pd.read_csv("/content/funcionario.csv",delimiter = ';')
df_produto = pd.read_csv("/content/produto.csv",delimiter = ';')
df_servico = pd.read_csv("/content/servico.csv",delimiter = ';')

# %%
df_servico.to_sql("servico",engine,if_exists="append")
df_funcionario.to_sql("funcionario",engine,if_exists="append")
df_produto.to_sql("produto",engine,if_exists="append")
df_servico.to_sql("servico",engine,if_exists="append")

# %%
#Gravando no banco de dados
df_funcionario_stage.to_sql("funcionario_stage",engine2,if_exists="append")
df_produto_stage.to_sql("produto_stage",engine2,if_exists="append")
df_servico_stage.to_sql("servico_stage",engine2,if_exists="append")

# %%
#Gravando no banco de dados
df_funcionario_stage.to_sql("funcionario_stage",engine2,if_exists="append")
df_produto_stage.to_sql("produto_stage",engine2,if_exists="append")
df_servico_stage.to_sql("servico_stage",engine2,if_exists="append")

# %%
df2.to_sql("funcionario_2021", con=engine, if_exists="replace")
